# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os

path = "gdrive/My Drive/3-tech/text-to-image/"
os.listdir(path)
# Out:
# ['setup.py',
#  'performance.png',
#  'image_from_text.py',
#  'tkinter_ui.py',
#  'requirements.txt',
#  'min_dalle_fine_tuning.ipynb',
#  'LICENSE',
#  'min_dalle.ipynb',
#  'README.md',
#  'examples',
#  'replicate',
#  'min_dalle']

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
1 cd% /content/gdrive/MyDrive/3-tech/text-to-image
# Out:
#   File "<ipython-input-15-219ce2a6ca25>", line 1
#     1 cd%/content/gdrive/MyDrive/3-tech/text-to-image
#        ^
# SyntaxError: invalid syntax

# %%
# !python image_from_text.py --text='bear reading a book in space, oil paint' --no-mega
# Out:
# python3: can't open file 'image_from_text.py': [Errno 2] No such file or directory

# %%
pip install emoji --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 216 kB 4.5 MB/s
# ...
#   Created wheel for emoji: filename=emoji-2.1.0-py3-none-any.whl size=212392 sha256=fc22773ac84ef6db9a90cc68146fd83cd35d1bb8099dcd9b36ec2ef83250d8e3
#   Stored in directory: /root/.cache/pip/wheels/77/75/99/51c2a119f4cfd3af7b49cc57e4f737bed7e40b348a85d82804
# Successfully built emoji
# ...
